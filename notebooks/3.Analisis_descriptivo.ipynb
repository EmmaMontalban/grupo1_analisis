# %% [markdown]
# ## Importar librerías

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Cargar datos

# %%
ruta = '../data/calidad_aire_2022_clean_nulos.csv'
df = pd.read_csv(ruta, delimiter=',')
df.head()
# Out:
#       ANO  MES  DIA  HORA DIA_SEMANA  ESTACION  SO2   NO2  PM2.5  PM10     O3  \
# 0  2022.0  1.0  1.0     0     Sabado       8.0  4.0  35.0   15.0  16.0  18.39
# 1  2022.0  1.0  1.0     1     Sabado       8.0  4.0  48.0   25.0  27.0   8.18
# 2  2022.0  1.0  1.0     2     Sabado       8.0  3.0  47.0   25.0  27.0   7.05
# 3  2022.0  1.0  1.0     3     Sabado       8.0  3.0  38.0   15.0  17.0  14.22
# 4  2022.0  1.0  1.0     4     Sabado       8.0  3.0  26.0    3.0   5.0  24.66
#
#    TEMPERATURA  PRECIPITACION  DIR_VIENTO  VEL_VIENTO  ICA_SO2  ICA_PM10  \
# 0         11.1            0.0         9.4        2.57      3.2      32.0
# 1         11.1            0.0         9.4        2.57      3.2      54.0
# 2         11.1            0.0         9.4        2.57      2.4      54.0
# 3         11.1            0.0         9.4        2.57      2.4      34.0
# 4         11.1            0.0         9.4        2.57      2.4      10.0
#
#    ICA_O3  ICA_NO2    ICA
# 0   15.32     87.5  34.51
# ...
