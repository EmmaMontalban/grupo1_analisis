# %%
import pandas as pd

# %%
pd.read_excel('../data/Vehiculos/Parquevehiculos2014.xlsx')
# Out:
#    'V.4. Parque de vehículos, distribuidos por provincias y tipos'
# 0                                                 NaN               \
# 1                                          PROVINCIAS
# 2                                         Araba/Álava
# 3                                            Albacete
# 4                                    Alicante/Alacant
# 5                                             Almeria
# 6                                               Avila
# 7                                             Badajoz
# 8                                     Balears (Illes)
# 9                                           Barcelona
# 10                                             Burgos
# 11                                            Caceres
# 12                                              Cadiz
# 13                                 Castellon/Castello
# 14                                        Ciudad Real
# 15                                            Cordoba
# ...
