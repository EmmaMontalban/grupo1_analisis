# %%
import pandas as pd 
import numpy as np
import os

# %%
df_aire = pd.read_csv('../data/aire_2022.csv')
df_aire.head(2)
# Out:
#    Unnamed: 0    CODIGO                FECHA     ANO  MES   DIA DIA_SEMANA  \
# 0           0  28079004  2022-03-25 00:00:00  2022.0  3.0  25.0    Viernes
# 1           1  28079004  2022-03-25 01:00:00  2022.0  3.0  25.0    Viernes
#
#    HORA  ESTACION  SO2  PM10  O3  NO2  PM2.5  ICA_SO2  ICA_NO2  ICA_PM10  \
# 0     0       4.0  NaN   NaN NaN  NaN    NaN      NaN      NaN       NaN
# 1     1       4.0  NaN   NaN NaN  NaN    NaN      NaN      NaN       NaN
#
#    ICA_O3  ICA
# 0     NaN  NaN
# 1     NaN  NaN

# %%
df_aire.drop("Unnamed: 0", axis=1, inplace=True)
# df_aire = df_aire.rename(columns={'Unnamed: 0': 'ID'})
df_aire.head(2)
# Out:
#      CODIGO                FECHA     ANO  MES   DIA DIA_SEMANA  HORA  \
# 0  28079004  2022-03-25 00:00:00  2022.0  3.0  25.0    Viernes     0
# 1  28079004  2022-03-25 01:00:00  2022.0  3.0  25.0    Viernes     1
#
#    ESTACION  SO2  PM10  O3  NO2  PM2.5  ICA_SO2  ICA_NO2  ICA_PM10  ICA_O3  \
# 0       4.0  NaN   NaN NaN  NaN    NaN      NaN      NaN       NaN     NaN
# 1       4.0  NaN   NaN NaN  NaN    NaN      NaN      NaN       NaN     NaN
#
#    ICA
# 0  NaN
# 1  NaN

# %%
df_aire.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 109152 entries, 0 to 109151
# Data columns (total 18 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   CODIGO      109152 non-null  int64
#  1   FECHA       109152 non-null  object
#  2   ANO         109152 non-null  float64
#  3   MES         109152 non-null  float64
#  4   DIA         109152 non-null  float64
#  5   DIA_SEMANA  109152 non-null  object
#  6   HORA        109152 non-null  int64
#  7   ESTACION    109152 non-null  float64
#  8   SO2         31903 non-null   float64
#  9   PM10        47625 non-null   float64
#  10  O3          75230 non-null   float64
#  11  NO2         108055 non-null  float64
#  12  PM2.5       23540 non-null   float64
#  13  ICA_SO2     31903 non-null   float64
#  14  ICA_NO2     108055 non-null  float64
#  15  ICA_PM10    47625 non-null   float64
#  16  ICA_O3      75230 non-null   float64
#  17  ICA         7329 non-null    float64
# ...

# %%
df_meteo = pd.read_csv('../data/meteo_2022.csv')
df_meteo.head(2)
# Out:
#    Unnamed: 0    CODIGO                FECHA     ANO  MES   DIA  HORA  \
# 0           0  28079004  2022-03-25 00:00:00  2022.0  3.0  25.0     0
# 1           1  28079004  2022-03-25 01:00:00  2022.0  3.0  25.0     1
#
#    ESTACION  VEL_VIENTO  DIR_VIENTO  TEMPERATURA  HUMEDAD  PRESION  \
# 0       4.0         NaN         NaN          NaN      NaN      NaN
# 1       4.0         NaN         NaN          NaN      NaN      NaN
#
#    PRECIPITACION DIA_SEMANA
# 0            NaN    Viernes
# 1            NaN    Viernes

# %%
df_meteo.drop("Unnamed: 0", axis=1, inplace=True)
df_meteo.head(2)
# Out:
#      CODIGO                FECHA     ANO  MES   DIA  HORA  ESTACION  \
# 0  28079004  2022-03-25 00:00:00  2022.0  3.0  25.0     0       4.0
# 1  28079004  2022-03-25 01:00:00  2022.0  3.0  25.0     1       4.0
#
#    VEL_VIENTO  DIR_VIENTO  TEMPERATURA  HUMEDAD  PRESION  PRECIPITACION  \
# 0         NaN         NaN          NaN      NaN      NaN            NaN
# 1         NaN         NaN          NaN      NaN      NaN            NaN
#
#   DIA_SEMANA
# 0    Viernes
# 1    Viernes

# %%
df_cali_aire = pd.concat([df_aire, df_meteo], ignore_index=True)
df_cali_aire.head(2)
# Out:
#      CODIGO                FECHA     ANO  MES   DIA DIA_SEMANA  HORA  \
# 0  28079004  2022-03-25 00:00:00  2022.0  3.0  25.0    Viernes     0
# 1  28079004  2022-03-25 01:00:00  2022.0  3.0  25.0    Viernes     1
#
#    ESTACION  SO2  PM10  ...  ICA_NO2  ICA_PM10  ICA_O3  ICA  VEL_VIENTO  \
# 0       4.0  NaN   NaN  ...      NaN       NaN     NaN  NaN         NaN
# 1       4.0  NaN   NaN  ...      NaN       NaN     NaN  NaN         NaN
#
#    DIR_VIENTO  TEMPERATURA  HUMEDAD  PRESION  PRECIPITACION
# 0         NaN          NaN      NaN      NaN            NaN
# 1         NaN          NaN      NaN      NaN            NaN
#
# [2 rows x 24 columns]

# %%
df_cali_aire.columns
# Out:
# Index(['CODIGO', 'FECHA', 'ANO', 'MES', 'DIA', 'DIA_SEMANA', 'HORA',
#        'ESTACION', 'SO2', 'PM10', 'O3', 'NO2', 'PM2.5', 'ICA_SO2', 'ICA_NO2',
#        'ICA_PM10', 'ICA_O3', 'ICA', 'VEL_VIENTO', 'DIR_VIENTO', 'TEMPERATURA',
#        'HUMEDAD', 'PRESION', 'PRECIPITACION'],
#       dtype='object')

# %%
df_cali_aire.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 209544 entries, 0 to 209543
# Data columns (total 24 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   CODIGO         209544 non-null  int64
#  1   FECHA          209544 non-null  object
#  2   ANO            209544 non-null  float64
#  3   MES            209544 non-null  float64
#  4   DIA            209544 non-null  float64
#  5   DIA_SEMANA     209544 non-null  object
#  6   HORA           209544 non-null  int64
#  7   ESTACION       209544 non-null  float64
#  8   SO2            31903 non-null   float64
#  9   PM10           47625 non-null   float64
#  10  O3             75230 non-null   float64
#  11  NO2            108055 non-null  float64
#  12  PM2.5          23540 non-null   float64
#  13  ICA_SO2        31903 non-null   float64
#  14  ICA_NO2        108055 non-null  float64
#  15  ICA_PM10       47625 non-null   float64
#  16  ICA_O3         75230 non-null   float64
# ...

# %%
df_cali_aire.describe()
# Out:
#              CODIGO       ANO            MES            DIA           HORA  \
# count  2.095440e+05  209544.0  209544.000000  209544.000000  209544.000000
# mean   2.807903e+07    2022.0       6.588707      15.719849      11.500000
# std    1.787829e+01       0.0       3.455271       8.810636       6.922203
# min    2.807900e+07    2022.0       1.000000       1.000000       0.000000
# 25%    2.807902e+07    2022.0       4.000000       8.000000       5.750000
# 50%    2.807904e+07    2022.0       7.000000      16.000000      11.500000
# 75%    2.807905e+07    2022.0      10.000000      23.000000      17.250000
# max    2.807906e+07    2022.0      12.000000      31.000000      23.000000
#
#             ESTACION           SO2          PM10            O3            NO2  \
# count  209544.000000  31903.000000  47625.000000  75230.000000  108055.000000
# mean       34.287596      3.723694     21.621333     52.960320      26.708389
# ...

# %%
df_cali_aire.shape
# Out:
# (209544, 24)
