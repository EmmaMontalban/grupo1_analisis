# %%
import pandas as pd
import os

# %%
df_estaciones = pd.read_csv('../data/estaciones.csv', delimiter=';')
df_estaciones.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24 entries, 0 to 23
# Data columns (total 25 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   CODIGO               24 non-null     int64
#  1   CODIGO_CORTO         24 non-null     int64
#  2   ESTACION             24 non-null     object
#  3   DIRECCION            24 non-null     object
#  4   LONGITUD_ETRS89      24 non-null     object
#  5   LATITUD_ETRS89       24 non-null     object
#  6   ALTITUD              24 non-null     int64
#  7   COD_TIPO             24 non-null     object
#  8   NOM_TIPO             24 non-null     object
#  9   NO2                  24 non-null     object
#  10  SO2                  5 non-null      object
#  11  CO                   5 non-null      object
#  12  PM10                 13 non-null     object
#  13  PM2_5                8 non-null      object
#  14  O3                   13 non-null     object
#  15  BTX                  6 non-null      object
#  16  COD_VIA              24 non-null     int64
#  17  VIA_CLASE            23 non-null     object
#  18  VIA_PAR              22 non-null     object
#  19  VIA_NOMBRE           23 non-null     object
#  20  Fecha alta           24 non-null     object
#  21  COORDENADA_X_ETRS89  24 non-null     object
#  22  COORDENADA_Y_ETRS89  24 non-null     object
#  23  LONGITUD             24 non-null     float64
#  24  LATITUD              24 non-null     float64
# dtypes: float64(2), int64(4), object(19)
# memory usage: 4.8+ KB

# %%
df_estaciones.head(2)
# Out:
#      CODIGO  CODIGO_CORTO          ESTACION                        DIRECCION
# 0  28079004             4   Plaza de España                  Plaza de España  \
# 1  28079008             8  Escuelas Aguirre  Entre C/ Alcalá y C/ O’ Donell
#
#   LONGITUD_ETRS89 LATITUD_ETRS89  ALTITUD COD_TIPO        NOM_TIPO NO2  ...
# 0    3°42'43.91"O  40°25'25.98"N      637       UT  Urbana tráfico   X  ...  \
# 1    3°40'56.22"O  40°25'17.63"N      672       UT  Urbana tráfico   X  ...
#
#    BTX COD_VIA VIA_CLASE VIA_PAR VIA_NOMBRE  Fecha alta  COORDENADA_X_ETRS89
# 0  NaN  273600     PLAZA      DE     ESPAÑA  01/12/1998          439579,3291  \
# 1    X   18900     CALLE      DE     ALCALA  01/12/1998          442117,2366
#
#   COORDENADA_Y_ETRS89  LONGITUD    LATITUD
# 0         4475049,263 -3.712257  40.423882
# 1         4474770,696 -3.682316  40.421553
#
# [2 rows x 25 columns]

# %%
file_names = os.listdir('../data/aire/')
file_names
# Out:
# ['Madrid2014.csv',
#  'Madrid2015.csv',
#  'Madrid2016.csv',
#  'Madrid2017.csv',
#  'Madrid2018.CSV',
#  'Madrid2019.csv',
#  'Madrid2020.csv',
#  'Madrid2021.csv',
#  'Madrid2022.csv',
#  'Madrid2023.csv']

# %%
df_aire = pd.DataFrame()
for file_name in file_names:
    df_current = pd.read_csv('../data/Aire/' + file_name, delimiter=';')
    print(file_name, df_current.shape)
    df_aire = pd.concat([df_aire, df_current], ignore_index=True)
# Out:
# Madrid2014.csv (1805, 69)
# Madrid2015.csv (1812, 69)
# Madrid2016.csv (1812, 69)
# Madrid2017.csv (1812, 69)
# Madrid2018.CSV (1806, 69)
# Madrid2019.csv (1836, 69)
# Madrid2020.csv (1836, 69)
# Madrid2021.csv (1616, 69)
# Madrid2022.csv (1566, 69)
# Madrid2023.csv (522, 69)

# %%
df_aire.shape
# Out:
# (16423, 70)

# %%
df_aire.head(2)
# Out:
#    MUNICIPIO  ESTACION  MAGNITUD PUNTO_MUESTREO   ANO  MES