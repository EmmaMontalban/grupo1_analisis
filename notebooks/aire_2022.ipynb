# %% [markdown]
# ## Importar librerías

# %%
import pandas as pd
import numpy as np
import os

# %% [markdown]
# ## Cargar datos

# %%
file_names = os.listdir('../data/aire/')
file_names
# Out:
# ['abr_mo22.csv',
#  'ago_mo22.csv',
#  'dic_mo22.csv',
#  'ene_mo22.csv',
#  'feb_mo22.csv',
#  'jul_mo22.csv',
#  'jun_mo22.csv',
#  'mar_mo22.csv',
#  'may_mo22.csv',
#  'nov_mo22.csv',
#  'oct_mo22.csv',
#  'sep_mo22.csv']

# %% [markdown]
# ## Crear único dataset con los los datos del año 2022
# Recorrer la lista files_names para crear un único dataset

# %%
df_aire = pd.DataFrame()
for file_name in file_names:
    df_current = pd.read_csv('../data/aire/' + file_name, delimiter=';')
    print(file_name, df_current.shape)
    df_aire = pd.concat([df_aire, df_current], ignore_index=True)
df_aire.head(3)
# Out:
# abr_mo22.csv (3951, 56)
# ago_mo22.csv (3960, 56)
# dic_mo22.csv (4092, 56)
# ene_mo22.csv (3929, 56)
# feb_mo22.csv (3556, 56)
# jul_mo22.csv (3968, 56)
# jun_mo22.csv (3872, 56)
# mar_mo22.csv (3946, 56)
# may_mo22.csv (4059, 56)
# nov_mo22.csv (3960, 56)
# oct_mo22.csv (4092, 56)
# sep_mo22.csv (3838, 56)
#    PROVINCIA  MUNICIPIO  ESTACION  MAGNITUD PUNTO_MUESTREO   ANO  MES  DIA  \
# 0         28         79         4         1  28079004_1_38  2022    4    1
# 1         28         79         4         1  28079004_1_38  2022    4    2
# 2         28         79         4         1  28079004_1_38  2022    4    3
#
#    H01 V01  ...  H20 V20  H21 V21  H22 V22  H23 V23  H24 V24
# 0  2.0   V  ...  2.0   V  2.0   V  2.0   V  2.0   V  1.0   V
# 1  1.0   V  ...  2.0   V  2.0   V  2.0   V  2.0   V  1.0   V
# 2  1.0   V  ...  2.0   V  2.0   V  2.0   V  2.0   V  1.0   V
#
# [3 rows x 56 columns]

# %% [markdown]
# ## Seleccionar datos:
#
# Nos quedamos con los parámetros que nos interesan: SO2: Dióxido de Azufre, NO2: Dióxido de Nitrógeno, PM2.5: Partículas < 2.5 μm, PM10: Partículas < 10 μm, O3: Ozono

# %%
df_aire = df_aire[(df_aire['MAGNITUD'] == 1) | (df_aire['MAGNITUD'] == 8) | (df_aire['MAGNITUD'] == 9) | (df_aire['MAGNITUD'] == 10) | (df_aire['MAGNITUD'] == 14)]
df_aire.head()
# Out:
#    PROVINCIA  MUNICIPIO  ESTACION  MAGNITUD PUNTO_MUESTREO   ANO  MES  DIA  \
# 0         28         79         4         1  28079004_1_38  2022    4    1
# 1         28         79         4         1  28079004_1_38  2022    4    2
# 2         28         79         4         1  28079004_1_38  2022    4    3
# 3         28         79         4         1  28079004_1_38  2022    4    4
# 4         28         79         4         1  28079004_1_38  2022    4    5
#
#    H01 V01  ...  H20 V20  H21 V21  H22 V22  H23 V23  H24 V24
# 0  2.0   V  ...  2.0   V  2.0   V  2.0   V  2.0   V  1.0   V
# 1  1.0   V  ...  2.0   V  2.0   V  2.0   V  2.0   V  1.0   V
# 2  1.0   V  ...  2.0   V  2.0   V  2.0   V  2.0   V  1.0   V
# 3  1.0   V  ...  2.0   V  2.0   V  2.0   V  2.0   V  2.0   V
# 4  1.0   V  ...  2.0   V  2.0   V  2.0   V  2.0   V  2.0   V
#
# [5 rows x 56 columns]

# %% [markdown]
# ## Nos quedamos con los parámetros de las estaciones que nos interesan:
#
# 4, 8, 16, 18, 24, 35, 36, 38, 39, 54, 55, 58, 59

# %%
df_aire  = df_aire[(df_aire['ESTACION'] == 4) | (df_aire['ESTACION'] == 8) | (df_aire['ESTACION'] == 16) | (df_aire['ESTACION'] == 18) | 
        (df_aire['ESTACION'] == 24 ) | (df_aire['ESTACION'] == 35) | (df_aire['ESTACION'] == 36) | (df_aire['ESTACION'] == 38) | 
        (df_aire['ESTACION'] == 39 ) | (df_aire['ESTACION'] == 54) | (df_aire['ESTACION'] == 55) | (df_aire['ESTACION'] == 58) | 
        (df_aire['ESTACION'] == 59 )]
df_aire.head()
# Out:
#    PROVINCIA  MUNICIPIO  ESTACION  MAGNITUD PUNTO_MUESTREO   ANO  MES  DIA  \
# 0         28         79         4         1  28079004_1_38  2022    4    1
# 1         28         79         4         1  28079004_1_38  2022    4    2
# 2         28         79         4         1  28079004_1_38  2022    4    3
# 3         28         79         4         1  28079004_1_38  2022    4    4
# 4         28         79         4         1  28079004_1_38  2022    4    5
#
#    H01 V01  ...  H20 V20  H21 V21  H22 V22  H23 V23  H24 V24
# 0  2.0   V  ...  2.0   V  2.0   V  2.0   V  2.0   V  1.0   V
# 1  1.0   V  ...  2.0   V  2.0   V  2.0   V  2.0   V  1.0   V
# 2  1.0   V  ...  2.0   V  2.0   V  2.0   V  2.0   V  1.0   V
# 3  1.0   V  ...  2.0   V  2.0   V  2.0   V  2.0   V  2.0   V
# 4  1.0   V  ...  2.0   V  2.0   V  2.0   V  2.0   V  2.0   V
#
# [5 rows x 56 columns]

# %% [markdown]
# ## Crear una nueva columna fecha
# Con formato datetime

# %%
df_aire['FECHA'] = pd.to_datetime(df_aire[['ANO','MES','DIA']].rename(columns = {'ANO': 'YEAR', 'MES': 'MONTH', 'DIA': 'DAY'}))

# %% [markdown]
# ## Preparación de los datos de salida:
# * Extraer los datos de las medidas tomadas
# * Crear dataset auxiliar con los datos extraídos y las nuevas   columnas creadas.

# %%
data_columns = [ 'H01', 'H02', 'H03', 'H04', 'H05', 'H06', 'H07', 'H08', 'H09', 'H10', 'H11', 'H12', 'H13', 'H14', 'H15', 'H16', 'H17', 'H18', 'H19', 'H20', 'H21', 'H22', 'H23', 'H24'] # feature
veri_columns = [ 'V01', 'V02', 'V03', 'V04', 'V05', 'V06', 'V07', 'V08', 'V09', 'V10', 'V11', 'V12', 'V13', 'V14', 'V15', 'V16', 'V17', 'V18', 'V19', 'V20', 'V21', 'V22', 'V23', 'V24']

hora_column = np.arange(1,25) # feature label

data = pd.DataFrame(columns=['HORA', 'DATO', 'VERIFICADO'])
aux = pd.DataFrame(columns=['ANO', 'MES', 'DIA', 'HORA', 'DATO', 'VERIFICADO', 'ESTACION']) # aux de próxima fila a ser añadida
for  (h,d,v) in zip(hora_column, data_columns, veri_columns): 
    aux
    aux['DATO'] = df_aire [ data_columns[h-1] ] 
    aux[['CODIGO', 'MAGNITUD', 'TECNICA']] = df_aire['PUNTO_MUESTREO'].str.split('_', n=2, expand=True)
    aux['VERIFICADO'] = df_aire [ veri_columns[h-1] ] 
    aux['HORA'] = h-1
    aux[['ANO', 'MES', 'DIA']] = df_aire[['ANO','MES','DIA']]
    #aux['MAGNITUD'] = df_aire ['MAGNITUD']
    aux['ESTACION'] = df_aire ['ESTACION']
    data = pd.concat([data, aux], ignore_index=True)
data = data.astype({'HORA': 'int32'}, copy = False)

data.head()
# Out:
#    HORA  DATO VERIFICADO     ANO  MES  DIA  ESTACION    CODIGO MAGNITUD  \
# 0     0   2.0          V  2022.0  4.0  1.0       4.0  28079004        1
# 1     0   1.0          V  2022.0  4.0  2.0       4.0  28079004        1
# 2     0   1.0          V  2022.0  4.0  3.0       4.0  28079004        1
# 3     0   1.0          V  2022.0  4.0  4.0       4.0  28079004        1
# 4     0   1.0          V  2022.0  4.0  5.0       4.0  28079004        1
#
#   TECNICA
# 0      38
# 1      38
# 2      38
# 3      38
# 4      38

# %% [markdown]
# ## Añadir la columna fecha en formato datetime al nuevo dataset

# %%
data['FECHA'] = pd.to_datetime(data[['ANO','MES','DIA','HORA']].rename(columns = {'ANO': 'year', 'MES': 'month','DIA': 'day', 'HORA': 'hour'}))
data.head()
# Out:
#    HORA  DATO VERIFICADO     ANO  MES  DIA  ESTACION    CODIGO MAGNITUD  \
# 0     0   2.0          V  2022.0  4.0  1.0       4.0  28079004        1
# 1     0   1.0          V  2022.0  4.0  2.0       4.0  28079004        1
# 2     0   1.0          V  2022.0  4.0  3.0       4.0  28079004        1
# 3     0   1.0          V  2022.0  4.0  4.0       4.0  28079004        1
# 4     0   1.0          V  2022.0  4.0  5.0       4.0  28079004        1
#
#   TECNICA      FECHA
# 0      38 2022-04-01
# 1      38 2022-04-02
# 2      38 2022-04-03
# 3      38 2022-04-04
# 4      38 2022-04-05

# %% [markdown]
# ## Ordenar los datos por orden cronológico

# %%
data = data.sort_values(['FECHA','HORA'])
data.head()
# Out:
#       HORA   DATO VERIFICADO     ANO  MES  DIA  ESTACION    CODIGO MAGNITUD  \
# 3154     0   4.00          V  2022.0  1.0  1.0       8.0  28079008        1
# 3185     0  35.00          V  2022.0  1.0  1.0       8.0  28079008        8
# 3216     0  15.00          V  2022.0  1.0  1.0       8.0  28079008        9
# 3247     0  16.00          V  2022.0  1.0  1.0       8.0  28079008       10
# 3278     0  18.39          V  2022.0  1.0  1.0       8.0  28079008       14
#
#      TECNICA      FECHA
# 3154      38 2022-01-01
# 3185       8 2022-01-01
# 3216      47 2022-01-01
# 3247      47 2022-01-01
# 3278       6 2022-01-01

# %% [markdown]
# ## Marcar datos no válidos en el DataFrame:
# * Datos no verificados

# %%
data.loc[data['VERIFICADO'] != 'V', ['DATO']] = np.nan
data.loc[data['VERIFICADO'] != 'V']
# Out:
#         HORA  DATO VERIFICADO     ANO   MES   DIA  ESTACION    CODIGO  \
# 3402       0   NaN          N  2022.0   1.0   1.0      18.0  28079018
# 15771      1   NaN          N  2022.0   1.0   1.0      18.0  28079018
# 28140      2   NaN          N  2022.0   1.0   1.0      18.0  28079018
# 40696      3   NaN          N  2022.0   1.0   2.0      35.0  28079035
# 275707    22   NaN          N  2022.0   1.0   2.0      35.0  28079035
# ...      ...   ...        ...     ...   ...   ...       ...       ...
# 114473     9   NaN          N  2022.0  12.0  30.0      59.0  28079059
# 126811    10   NaN          N  2022.0  12.0  30.0      59.0  28079059
# 126842    10   NaN          N  2022.0  12.0  30.0      59.0  28079059
# 139180    11   NaN          N  2022.0  12.0  30.0      59.0  28079059
# 287330    23   NaN          N  2022.0  12.0  31.0      38.0  28079038
#
#        MAGNITUD TECNICA               FECHA
# 3402         10      47 2022-01-01 00:00:00
# 15771        10      47 2022-01-01 01:00:00
# 28140        10      47 2022-01-01 02:00:00
# 40696         1      38 2022-01-02 03:00:00
# 275707        1      38 2022-01-02 22:00:00
# ...         ...     ...                 ...
# 114473       14       6 2022-12-30 09:00:00
# 126811        8       8 2022-12-30 10:00:00
# 126842       14       6 2022-12-30 10:00:00
# 139180        8       8 2022-12-30 11:00:00
# 287330       10      47 2022-12-31 23:00:00
#
# [10503 rows x 11 columns]

# %% [markdown]
# ## Borrar columna verificado

# %%
data = data.drop('VERIFICADO', axis=1)
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 296856 entries, 3154 to 287640
# Data columns (total 10 columns):
#  #   Column    Non-Null Count   Dtype
# ---  ------    --------------   -----
#  0   HORA      296856 non-null  int32
#  1   DATO      286353 non-null  float64
#  2   ANO       296856 non-null  float64
#  3   MES       296856 non-null  float64
#  4   DIA       296856 non-null  float64
#  5   ESTACION  296856 non-null  float64
#  6   CODIGO    296856 non-null  object
#  7   MAGNITUD  296856 non-null  object
#  8   TECNICA   296856 non-null  object
#  9   FECHA     296856 non-null  datetime64[ns]
# dtypes: datetime64[ns](1), float64(5), int32(1), object(3)
# memory usage: 23.8+ MB

# %% [markdown]
# ## Añadir columnas que faltan y formatearlas,

# %%
data = data.set_index(['CODIGO','FECHA', 'ANO', 'MES', 'DIA', 'HORA', 'ESTACION','MAGNITUD'])['DATO'].unstack(level=-1).reset_index()
data.head()
# Out:
# MAGNITUD    CODIGO               FECHA     ANO  MES   DIA  HORA  ESTACION   1  \
# 0         28079004 2022-03-25 00:00:00  2022.0  3.0  25.0     0       4.0 NaN
# 1         28079004 2022-03-25 01:00:00  2022.0  3.0  25.0     1       4.0 NaN
# 2         28079004 2022-03-25 02:00:00  2022.0  3.0  25.0     2       4.0 NaN
# 3         28079004 2022-03-25 03:00:00  2022.0  3.0  25.0     3       4.0 NaN
# 4         28079004 2022-03-25 04:00:00  2022.0  3.0  25.0     4       4.0 NaN
#
# MAGNITUD  10  14   8   9
# 0        NaN NaN NaN NaN
# 1        NaN NaN NaN NaN
# 2        NaN NaN NaN NaN
# 3        NaN NaN NaN NaN
# 4        NaN NaN NaN NaN

# %% [markdown]
# ## Renombrar columnas con los contaminantes

# %%
data = data.rename(columns={'1': 'SO2', '10': 'PM10', '8': 'NO2', '9': 'PM2.5',  '14': 'O3'}, copy = False, errors = 'raise')
data.head()
# Out:
# MAGNITUD    CODIGO               FECHA     ANO  MES   DIA  HORA  ESTACION  \
# 0         28079004 2022-03-25 00:00:00  2022.0  3.0  25.0     0       4.0
# 1         28079004 2022-03-25 01:00:00  2022.0  3.0  25.0     1       4.0
# 2         28079004 2022-03-25 02:00:00  2022.0  3.0  25.0     2       4.0
# 3         28079004 2022-03-25 03:00:00  2022.0  3.0  25.0     3       4.0
# 4         28079004 2022-03-25 04:00:00  2022.0  3.0  25.0     4       4.0
#
# MAGNITUD  SO2  PM10  O3  NO2  PM2.5
# 0         NaN   NaN NaN  NaN    NaN
# 1         NaN   NaN NaN  NaN    NaN
# 2         NaN   NaN NaN  NaN    NaN
# 3         NaN   NaN NaN  NaN    NaN
# 4         NaN   NaN NaN  NaN    NaN

# %% [markdown]
# ## Añadir columna para el día de la semana

# %%
dates = data['FECHA'].dt.to_pydatetime()
days_of_week = ['Lunes', 'Martes', 'Miercoles', 'Jueves', 'Viernes', 'Sabado', 'Domingo']
data['DIA_SEMANA'] = np.array([days_of_week[d.weekday()] for d in dates])
data.head()
# Out:
# MAGNITUD    CODIGO               FECHA     ANO  MES   DIA  HORA  ESTACION  \
# 0         28079004 2022-03-25 00:00:00  2022.0  3.0  25.0     0       4.0
# 1         28079004 2022-03-25 01:00:00  2022.0  3.0  25.0     1       4.0
# 2         28079004 2022-03-25 02:00:00  2022.0  3.0  25.0     2       4.0
# 3         28079004 2022-03-25 03:00:00  2022.0  3.0  25.0     3       4.0
# 4         28079004 2022-03-25 04:00:00  2022.0  3.0  25.0     4       4.0
#
# MAGNITUD  SO2  PM10  O3  NO2  PM2.5 DIA_SEMANA
# 0         NaN   NaN NaN  NaN    NaN    Viernes
# 1         NaN   NaN NaN  NaN    NaN    Viernes
# 2         NaN   NaN NaN  NaN    NaN    Viernes
# 3         NaN   NaN NaN  NaN    NaN    Viernes
# 4         NaN   NaN NaN  NaN    NaN    Viernes

# %%
dia_semana = data.pop('DIA_SEMANA')
data.insert(5, 'DIA_SEMANA', dia_semana)
data.head()
# Out:
# MAGNITUD    CODIGO               FECHA     ANO  MES   DIA DIA_SEMANA  HORA  \
# 0         28079004 2022-03-25 00:00:00  2022.0  3.0  25.0    Viernes     0
# 1         28079004 2022-03-25 01:00:00  2022.0  3.0  25.0    Viernes     1
# 2         28079004 2022-03-25 02:00:00  2022.0  3.0  25.0    Viernes     2
# 3         28079004 2022-03-25 03:00:00  2022.0  3.0  25.0    Viernes     3
# 4         28079004 2022-03-25 04:00:00  2022.0  3.0  25.0    Viernes     4
#
# MAGNITUD  ESTACION  SO2  PM10  O3  NO2  PM2.5
# 0              4.0  NaN   NaN NaN  NaN    NaN
# 1              4.0  NaN   NaN NaN  NaN    NaN
# 2              4.0  NaN   NaN NaN  NaN    NaN
# 3              4.0  NaN   NaN NaN  NaN    NaN
# 4              4.0  NaN   NaN NaN  NaN    NaN

# %%
data.reset_index(drop=True)
data.head()
# Out:
# MAGNITUD    CODIGO               FECHA     ANO  MES   DIA DIA_SEMANA  HORA  \
# 0         28079004 2022-03-25 00:00:00  2022.0  3.0  25.0    Viernes     0
# 1         28079004 2022-03-25 01:00:00  2022.0  3.0  25.0    Viernes     1
# 2         28079004 2022-03-25 02:00:00  2022.0  3.0  25.0    Viernes     2
# 3         28079004 2022-03-25 03:00:00  2022.0  3.0  25.0    Viernes     3
# 4         28079004 2022-03-25 04:00:00  2022.0  3.0  25.0    Viernes     4
#
# MAGNITUD  ESTACION  SO2  PM10  O3  NO2  PM2.5
# 0              4.0  NaN   NaN NaN  NaN    NaN
# 1              4.0  NaN   NaN NaN  NaN    NaN
# 2              4.0  NaN   NaN NaN  NaN    NaN
# 3              4.0  NaN   NaN NaN  NaN    NaN
# 4              4.0  NaN   NaN NaN  NaN    NaN

# %% [markdown]
# ## Datos no válidos

# %%
data.isnull().sum()
# Out:
# MAGNITUD
# CODIGO            0
# FECHA             0
# ANO               0
# MES               0
# DIA               0
# DIA_SEMANA        0
# HORA              0
# ESTACION          0
# SO2           77249
# PM10          61527
# O3            33922
# NO2            1097
# PM2.5         85612
# dtype: int64

# %% [markdown]
# ## Calcular ICA para cada componente:
# - ICA_SO2 = (Concentración_SO2 / Valor_Límite_SO2) * 100, Valor límite = 125 μg/m3
# - ICA_NO2 = (Concentración_NO2 / Valor_Límite_NO2) * 100, Valor límite = 40 μg/m3
# - ICA_PM10 = (Concentración_PM10 / Valor_Límite_PM10) * 100, Valor límite = 50 μg/m3
# - ICA_O3 = (Concentración_O3 / Valor_Límite_O3) * 100, Valor límite = 120 μg/m3

# %%
ica_so2 = (data['SO2']/125)*100
data['ICA_SO2'] = ica_so2
data.head()
# Out:
# MAGNITUD    CODIGO               FECHA     ANO  MES   DIA DIA_SEMANA  HORA  \
# 0         28079004 2022-03-25 00:00:00  2022.0  3.0  25.0    Viernes     0
# 1         28079004 2022-03-25 01:00:00  2022.0  3.0  25.0    Viernes     1
# 2         28079004 2022-03-25 02:00:00  2022.0  3.0  25.0    Viernes     2
# 3         28079004 2022-03-25 03:00:00  2022.0  3.0  25.0    Viernes     3
# 4         28079004 2022-03-25 04:00:00  2022.0  3.0  25.0    Viernes     4
#
# MAGNITUD  ESTACION  SO2  PM10  O3  NO2  PM2.5  ICA_SO2
# 0              4.0  NaN   NaN NaN  NaN    NaN      NaN
# 1              4.0  NaN   NaN NaN  NaN    NaN      NaN
# 2              4.0  NaN   NaN NaN  NaN    NaN      NaN
# 3              4.0  NaN   NaN NaN  NaN    NaN      NaN
# 4              4.0  NaN   NaN NaN  NaN    NaN      NaN

# %%
ica_no2 = (data['NO2']/40)*100
data['ICA_NO2'] = ica_no2
data.tail()
# Out:
# MAGNITUD    CODIGO               FECHA     ANO   MES   DIA DIA_SEMANA  HORA  \
# 109147    28079059 2022-12-31 19:00:00  2022.0  12.0  31.0     Sabado    19
# 109148    28079059 2022-12-31 20:00:00  2022.0  12.0  31.0     Sabado    20
# 109149    28079059 2022-12-31 21:00:00  2022.0  12.0  31.0     Sabado    21
# 109150    28079059 2022-12-31 22:00:00  2022.0  12.0  31.0     Sabado    22
# 109151    28079059 2022-12-31 23:00:00  2022.0  12.0  31.0     Sabado    23
#
# MAGNITUD  ESTACION  SO2  PM10     O3   NO2  PM2.5  ICA_SO2  ICA_NO2
# 109147        59.0  NaN   NaN   5.08  64.0    NaN      NaN    160.0
# 109148        59.0  NaN   NaN   3.75  72.0    NaN      NaN    180.0
# 109149        59.0  NaN   NaN   4.18  64.0    NaN      NaN    160.0
# 109150        59.0  NaN   NaN  17.03  35.0    NaN      NaN     87.5
# 109151        59.0  NaN   NaN  20.08  25.0    NaN      NaN     62.5

# %%
ica_pm10 = (data['PM10']/50)*100
data['ICA_PM10'] = ica_pm10
data.tail()
# Out:
# MAGNITUD    CODIGO               FECHA     ANO   MES   DIA DIA_SEMANA  HORA  \
# 109147    28079059 2022-12-31 19:00:00  2022.0  12.0  31.0     Sabado    19
# 109148    28079059 2022-12-31 20:00:00  2022.0  12.0  31.0     Sabado    20
# 109149    28079059 2022-12-31 21:00:00  2022.0  12.0  31.0     Sabado    21
# 109150    28079059 2022-12-31 22:00:00  2022.0  12.0  31.0     Sabado    22
# 109151    28079059 2022-12-31 23:00:00  2022.0  12.0  31.0     Sabado    23
#
# MAGNITUD  ESTACION  SO2  PM10     O3   NO2  PM2.5  ICA_SO2  ICA_NO2  ICA_PM10
# 109147        59.0  NaN   NaN   5.08  64.0    NaN      NaN    160.0       NaN
# 109148        59.0  NaN   NaN   3.75  72.0    NaN      NaN    180.0       NaN
# 109149        59.0  NaN   NaN   4.18  64.0    NaN      NaN    160.0       NaN
# 109150        59.0  NaN   NaN  17.03  35.0    NaN      NaN     87.5       NaN
# 109151        59.0  NaN   NaN  20.08  25.0    NaN      NaN     62.5       NaN

# %%
ica_o3 = (data['O3']/120)*100
data['ICA_O3'] = ica_o3
data.tail()
# Out:
# MAGNITUD    CODIGO               FECHA     ANO   MES   DIA DIA_SEMANA  HORA  \
# 109147    28079059 2022-12-31 19:00:00  2022.0  12.0  31.0     Sabado    19
# 109148    28079059 2022-12-31 20:00:00  2022.0  12.0  31.0     Sabado    20
# 109149    28079059 2022-12-31 21:00:00  2022.0  12.0  31.0     Sabado    21
# 109150    28079059 2022-12-31 22:00:00  2022.0  12.0  31.0     Sabado    22
# 109151    28079059 2022-12-31 23:00:00  2022.0  12.0  31.0     Sabado    23
#
# MAGNITUD  ESTACION  SO2  PM10     O3   NO2  PM2.5  ICA_SO2  ICA_NO2  ICA_PM10  \
# 109147        59.0  NaN   NaN   5.08  64.0    NaN      NaN    160.0       NaN
# 109148        59.0  NaN   NaN   3.75  72.0    NaN      NaN    180.0       NaN
# 109149        59.0  NaN   NaN   4.18  64.0    NaN      NaN    160.0       NaN
# 109150        59.0  NaN   NaN  17.03  35.0    NaN      NaN     87.5       NaN
# 109151        59.0  NaN   NaN  20.08  25.0    NaN      NaN     62.5       NaN
#
# MAGNITUD     ICA_O3
# 109147     4.233333
# 109148     3.125000
# 109149     3.483333
# 109150    14.191667
# 109151    16.733333

# %% [markdown]
# ## Calcular el indice de calidad del aire ICA:
# - ICA = (ICA_SO2 + ICA_NO2 + ICA_PM10 + ICA_O3) / 4

# %%
ica = (ica_so2 + ica_no2 + ica_pm10 + ica_o3) /4
data['ICA'] = ica
data.head(100)
# Out:
# MAGNITUD    CODIGO               FECHA     ANO  MES   DIA DIA_SEMANA  HORA  \
# 0         28079004 2022-03-25 00:00:00  2022.0  3.0  25.0    Viernes     0
# 1         28079004 2022-03-25 01:00:00  2022.0  3.0  25.0    Viernes     1
# 2         28079004 2022-03-25 02:00:00  2022.0  3.0  25.0    Viernes     2
# 3         28079004 2022-03-25 03:00:00  2022.0  3.0  25.0    Viernes     3
# 4         28079004 2022-03-25 04:00:00  2022.0  3.0  25.0    Viernes     4
# ..             ...                 ...     ...  ...   ...        ...   ...
# 95        28079004 2022-03-30 23:00:00  2022.0  3.0  30.0  Miercoles    23
# 96        28079004 2022-03-31 00:00:00  2022.0  3.0  31.0     Jueves     0
# 97        28079004 2022-03-31 01:00:00  2022.0  3.0  31.0     Jueves     1
# 98        28079004 2022-03-31 02:00:00  2022.0  3.0  31.0     Jueves     2
# 99        28079004 2022-03-31 03:00:00  2022.0  3.0  31.0     Jueves     3
#
# MAGNITUD  ESTACION  SO2  PM10  O3   NO2  PM2.5  ICA_SO2  ICA_NO2  ICA_PM10  \
# 0              4.0  NaN   NaN NaN   NaN    NaN      NaN      NaN       NaN
# 1              4.0  NaN   NaN NaN   NaN    NaN      NaN      NaN       NaN
# 2              4.0  NaN   NaN NaN   NaN    NaN      NaN      NaN       NaN
# 3              4.0  NaN   NaN NaN   NaN    NaN      NaN      NaN       NaN
# 4              4.0  NaN   NaN NaN   NaN    NaN      NaN      NaN       NaN
# ..             ...  ...   ...  ..   ...    ...      ...      ...       ...
# 95             4.0  2.0   NaN NaN  49.0    NaN      1.6    122.5       NaN
# 96             4.0  2.0   NaN NaN  25.0    NaN      1.6     62.5       NaN
# 97             4.0  2.0   NaN NaN  21.0    NaN      1.6     52.5       NaN
# 98             4.0  1.0   NaN NaN  29.0    NaN      0.8     72.5       NaN
# 99             4.0  1.0   NaN NaN  28.0    NaN      0.8     70.0       NaN
#
# MAGNITUD  ICA_O3  ICA
# 0            NaN  NaN
# 1            NaN  NaN
# 2            NaN  NaN
# 3            NaN  NaN
# 4            NaN  NaN
# ..           ...  ...
# 95           NaN  NaN
# 96           NaN  NaN
# 97           NaN  NaN
# 98           NaN  NaN
# 99           NaN  NaN
#
# [100 rows x 18 columns]

# %%
data.to_csv('../data/aire_2022.csv') # Salvado con todos los datos
